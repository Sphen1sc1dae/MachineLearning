# %% [markdown]
# ### PIL(Pillow) 를 이용한 Image 처리

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in C:\Users\aaago\miniconda3\Lib\site-packages (12.2.0)

# %%
from PIL import Image

# %%
# 이미지 불러오기
cat = Image.open('../Data/cat.png')
cat
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=169x158>

# %%
# Image Layer 확인
cat.getbands()
# Out:
# ('R', 'G', 'B')

# %%
cat.mode
# Out:
# 'RGB'

# %%
cat.size
# 이미지 해상도
# Out:
# (169, 158)

# %%
cat.filename
# Out:
# '../Data/cat.png'

# %%
cat.format
# Out:
# 'PNG'

# %% [markdown]
# > 이렇게 뒤에 ( )를 붙이지 않는 형태이면 클래스의 Property 인 것.

# %%
# Image Resize
cat_resize = cat.resize((169, 169))
cat_resize
# Out:
# <PIL.Image.Image image mode=RGB size=169x169>

# %%
# Image Rotate
cat_rotate = cat.rotate(45)
cat_rotate
# Out:
# <PIL.Image.Image image mode=RGB size=169x158>

# %%
# Numpy Arrray로 변경
import numpy as np
cat_array = np.array(cat)
cat_array
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], shape=(158, 169, 3), dtype=uint8)

# %%
# Color Transformation
cat.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=169x158>

# %%
cat.convert('RGBA')
# Out:
# <PIL.Image.Image image mode=RGBA size=169x158>
